# %% [markdown]
# # Exam Project — Data Analyst
# ### Brazilian E-Commerce Dataset (Olist)
#
# **Nama   : isi nama**
#
# **Tanggal : isi tanggal dan hari**
#
# ---
#
# ## Instruksi Umum
#
# - Kerjakan setiap section secara berurutan
# - **Wajib mengisi semua markdown cell** yang bertanda `Jawab di sini` — ini yang dinilai utama
# - Boleh menggunakan AI untuk bantu nulis kode, tapi insight dan storytelling harus dari pemikiranmu sendiri
# - Setiap visualisasi harus punya **judul, label sumbu x dan y**
# - Jalankan semua cell dari atas ke bawah sebelum submit
#
# ---

# %% [markdown]
# ## Instalasi Library
#
# Sebelum mulai, pastikan semua library sudah terinstall.
# Jalankan cell di bawah ini **sekali saja** di awal.
#
# > **Pakai macOS?** Kalau `pip` tidak dikenali, ganti dengan `pip3`:
# > ```
# > !pip3 install pandas numpy matplotlib seaborn
# > ```

# %%
# Jalankan cell ini sekali untuk install semua library
# Kalau error 'pip not found', ganti pip dengan pip3
# !pip install pandas numpy matplotlib seaborn

# %% [markdown]
# > **Untuk menjalankan Streamlit (`app.py`):**
# >
# > 1. Buka **Terminal** di Mac (tekan `Command + Space` → ketik `Terminal` → Enter)
# > 2. Terminal Mac pakai **zsh** — tidak perlu setting apapun, langsung bisa dipakai
# > 3. Install streamlit dulu (cukup sekali):
# >    ```
# >    pip3 install streamlit
# >    ```
# > 4. Masuk ke folder project:
# >    ```
# >    cd path/ke/folder/Exam-DataAnalyst
# >    ```
# > 5. Jalankan app:
# >    ```
# >    streamlit run app.py
# >    ```
# > 6. Browser akan otomatis terbuka di `http://localhost:8501`

# %% [markdown]
# ---
# ## Import Library
#
# > Import semua library yang kamu butuhkan di sini.
# > Library yang dibutuhkan: `pandas`, `numpy`, `matplotlib.pyplot`, `seaborn`

# %%
# import library di sini

# %% [markdown]
# ---
# # Section 1 — Data Understanding
#
# Sebelum mengolah data, pahami dulu isinya.
# Di section ini kamu akan melihat struktur, tipe data, dan isi dari ketiga dataset.

# %% [markdown]
# ### 1.1 Load Dataset
#
# > **Tip:** Gunakan `pd.read_csv('path/file.csv')` untuk membaca file CSV.
# > Ketiga file ada di folder `dataset/` :
# > - `dataset/orders.csv`
# > - `dataset/order_items.csv`
# > - `dataset/products.csv`

# %%
# load ketiga dataset di sini

# %% [markdown]
# ### 1.2 Eksplorasi Awal Setiap Tabel
#
# > **Tip:** Gunakan fungsi-fungsi berikut untuk eksplorasi:
# > - `.head()` — lihat 5 baris pertama
# > - `.shape` — lihat jumlah baris dan kolom
# > - `.info()` — lihat tipe data dan jumlah non-null
# > - `.describe()` — statistik deskriptif kolom numerik
# > - `.dtypes` — lihat tipe data setiap kolom
# >
# > Lakukan untuk **ketiga tabel**: orders, order_items, products

# %%
# eksplorasi orders

# %%
# eksplorasi order_items

# %%
# eksplorasi products

# %% [markdown]
# ### Jawab di sini — 1.3 Penjelasan Dataset
#
# **1. Dataset ini berisi informasi tentang apa?**
# *(Jelaskan isi masing-masing tabel: orders, order_items, products)*
#
# > *Klik 2x di sini untuk menulis jawabanmu*
#
#
# ---
#
# **2. Berapa total baris dan kolom di setiap tabel?**
#
# | Tabel | Baris | Kolom |
# |-------|-------|-------|
# | orders | isi di sini | isi di sini |
# | order_items | isi di sini | isi di sini |
# | products | isi di sini | isi di sini |
#
# ---
#
# **3. Kolom apa yang menghubungkan (join) ketiga tabel?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*
#
#
# ---
#
# **4. Pertanyaan bisnis apa yang bisa dijawab dari dataset ini? (minimal 3)**
#
# 1. isi di sini
# 2. isi di sini
# 3. isi di sini

# %% [markdown]
# ---
# # Section 2 — Data Preprocessing & Cleaning
#
# Di section ini kamu akan:
# 1. Cek dan tangani **missing values**
# 2. Cek dan hapus **duplikat**
# 3. Konversi **tipe data** (terutama kolom tanggal)
# 4. **Merge** ketiga tabel menjadi satu dataframe utama

# %% [markdown]
# ### 2.1 Cek Missing Values
#
# > **Tip:** Gunakan `.isnull().sum()` untuk melihat jumlah missing value per kolom.
# > Lakukan untuk ketiga tabel.

# %%
# cek missing values di ketiga tabel

# %% [markdown]
# ### Jawab di sini — 2.2 Analisis Missing Values
#
# **Kolom mana saja yang memiliki missing value?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*
#
#
# ---
#
# **Untuk missing value di orders (kolom tanggal delivery) — kenapa bisa kosong? Apakah wajar?**
#
# *Hint: Lihat kolom `order_status`. Order yang belum `delivered` tentu belum punya tanggal delivery.*
#
# > *Klik 2x di sini untuk menulis jawabanmu*
#
#
# ---
#
# **Apa keputusanmu untuk menangani setiap missing value? Jelaskan alasannya!**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ### 2.3 Tangani Missing Values
#
# > **Tip:**
# > - Isi dengan nilai tertentu: `df['kolom'].fillna('Unknown')`
# > - Hapus baris: `df.dropna(subset=['kolom'])`
# > - Isi dengan median: `df['kolom'].fillna(df['kolom'].median())`
# >
# > Setelah selesai, verifikasi dengan `.isnull().sum()` lagi.

# %%
# tangani missing values di sini

# %% [markdown]
# ### 2.4 Cek dan Hapus Duplikat
#
# > **Tip:**
# > - Cek: `df.duplicated().sum()`
# > - Hapus: `df.drop_duplicates(inplace=True)`

# %%
# cek dan hapus duplikat

# %% [markdown]
# ### 2.5 Konversi Tipe Data — DateTime
#
# > **Tip:** Kolom tanggal sekarang bertipe `object` (string). Harus dikonversi ke datetime.
# >
# > ```python
# > df['kolom_tanggal'] = pd.to_datetime(df['kolom_tanggal'])
# > ```
# >
# > Kolom tanggal yang perlu dikonversi ada di tabel `orders` dan `order_items`.
# >
# > Setelah konversi bisa ekstrak:
# > - `.dt.month` — angka bulan (1-12)
# > - `.dt.year` — tahun
# > - `.dt.to_period('M')` — periode bulan-tahun (misal: 2017-01)

# %%
# konversi kolom tanggal ke datetime

# %% [markdown]
# ### 2.6 Merge / Join Tabel
#
# > **Flow join:**
# > ```
# > orders --(order_id)--> order_items --(product_id)--> products
# > ```
# >
# > **Tip:** Gunakan `pd.merge()`:
# > ```python
# > df = pd.merge(tabel_kiri, tabel_kanan, on='kolom_kunci', how='left')
# > ```
# > - `how='left'` → semua data dari tabel kiri tetap ada, kanan menyesuaikan
# >
# > Lakukan 2 kali merge:
# > - **Step 1:** merge `orders` + `order_items` berdasarkan `order_id`
# > - **Step 2:** merge hasil step 1 + `products` berdasarkan `product_id`
# >
# > Setelah merge, cek `.shape` — pastikan jumlah baris masuk akal.

# %%
# Step 1: merge orders + order_items

# %%
# Step 2: merge hasil step 1 + products

# %%
# verifikasi hasil merge: cek shape, head(), dan kolom

# %% [markdown]
# ### Jawab di sini — 2.7 Refleksi Cleaning & Merge
#
# **Apa saja yang kamu lakukan di section cleaning ini?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*
#
#
# ---
#
# **Setelah merge, berapa total baris di dataframe final? Apakah sesuai ekspektasi?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*
#
#
# ---
#
# **Kenapa kita perlu merge ketiga tabel ini? Apa yang tidak bisa dianalisis kalau tidak di-merge?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ---
# # Section 3 — Exploratory Data Analysis (EDA)
#
# Di section ini kamu akan mengeksplorasi data dengan visualisasi dan operasi Pandas.
#
# **Wajib menggunakan (semua harus ada):**
# - `groupby()` + aggregasi (`sum`, `mean`, `count`)
# - `pivot_table()`
# - `crosstab()`
# - Minimal **5 visualisasi** — setiap chart harus punya judul dan label sumbu

# %% [markdown]
# ### 3.1 Distribusi Harga Produk
#
# > **Tip:** Buat 2 chart berdampingan menggunakan `plt.subplots(1, 2)`:
# > - Histogram: `sns.histplot()` — lihat sebaran harga
# > - Boxplot: `sns.boxplot()` — lihat outlier
# >
# > Kolom yang digunakan: `price`

# %%
# visualisasi distribusi harga — histogram + boxplot

# %% [markdown]
# ### Jawab di sini — Insight 3.1
#
# **Apa yang kamu lihat dari distribusi harga? Apakah ada outlier? Bagaimana pola sebarannya?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ### 3.2 Top 10 Kategori Produk Berdasarkan Revenue
#
# > **Tip:**
# > 1. Hitung total revenue per kategori menggunakan `groupby()` + `.sum()`
# > 2. Urutkan dari terbesar: `.sort_values(ascending=False)`
# > 3. Ambil 10 teratas: `.head(10)`
# > 4. Visualisasikan dengan `sns.barplot()` — horizontal (x=nilai, y=kategori)
# >
# > Kolom yang digunakan: `product_category_name`, `price`
# >
# > **Catatan:** Nama kategori dalam Bahasa Portugis. Beberapa terjemahan:
# > - `cama_mesa_banho` = bed/table/bath | `esporte_lazer` = sports & leisure
# > - `beleza_saude` = beauty & health | `informatica_acessorios` = computers & accessories
# > - `moveis_decoracao` = furniture & decor

# %%
# groupby kategori + sum revenue, lalu barplot top 10

# %% [markdown]
# ### Jawab di sini — Insight 3.2
#
# **Kategori apa yang menghasilkan revenue terbesar? Mengapa menurutmu kategori itu bisa unggul?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ### 3.3 Tren Jumlah Pesanan per Bulan
#
# > **Tip:**
# > 1. Ekstrak periode bulan-tahun dari kolom tanggal:
# >    ```python
# >    df['order_month'] = df['order_purchase_timestamp'].dt.to_period('M')
# >    ```
# > 2. Hitung jumlah **unik** order per bulan:
# >    ```python
# >    .groupby('order_month')['order_id'].nunique()
# >    ```
# > 3. Urutkan berdasarkan bulan: `.sort_index()`
# > 4. Plot line chart dengan `plt.plot()` — tambahkan `marker='o'`

# %%
# line chart tren pesanan per bulan

# %% [markdown]
# ### Jawab di sini — Insight 3.3
#
# **Bagaimana tren pesanan dari waktu ke waktu? Adakah bulan dengan lonjakan atau penurunan drastis? Apa kemungkinan penyebabnya?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ### 3.4 Distribusi Status Pesanan
#
# > **Tip:**
# > - Hitung frekuensi: `df['order_status'].value_counts()`
# > - Buat 2 chart berdampingan: bar chart + pie chart
# > - Pie chart: `plt.pie(values, labels=labels, autopct='%1.1f%%')`

# %%
# bar chart + pie chart distribusi status pesanan

# %% [markdown]
# ### Jawab di sini — Insight 3.4
#
# **Berapa persen pesanan yang berhasil delivered? Berapa yang canceled? Apa implikasinya untuk bisnis?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ### 3.5 Rata-rata Harga vs Freight Value per Kategori
#
# > **Tip:**
# > 1. Filter hanya top 10 kategori (dari analisis 3.2)
# > 2. Hitung rata-rata dengan `groupby()` pada **dua kolom sekaligus**:
# >    ```python
# >    df.groupby('product_category_name')[['price', 'freight_value']].mean()
# >    ```
# > 3. Plot grouped bar chart: `.plot(kind='bar')`
# > 4. Tambahkan legend untuk bedakan harga vs freight

# %%
# grouped bar chart: rata-rata price vs freight_value per kategori

# %% [markdown]
# ### Jawab di sini — Insight 3.5
#
# **Kategori mana yang memiliki ongkos kirim paling tinggi relatif terhadap harganya? Apakah wajar? Mengapa?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ### 3.6 Pivot Table — Revenue per Kategori per Bulan
#
# > **Tip:** Gunakan `pd.pivot_table()`:
# > ```python
# > pivot = pd.pivot_table(
# >     df,
# >     values='price',                    # nilai yang dihitung
# >     index='product_category_name',     # baris pivot
# >     columns='month_only',              # kolom pivot
# >     aggfunc='sum',                     # fungsi aggregasi
# >     fill_value=0                       # isi NaN dengan 0
# > )
# > ```
# >
# > Untuk kolom bulan, tambahkan dulu:
# > ```python
# > df['month_only'] = df['order_purchase_timestamp'].dt.month
# > ```
# >
# > Visualisasikan pivot table dengan `sns.heatmap(annot=True, fmt='.0f', cmap='YlOrRd')`

# %%
# pivot_table revenue per kategori per bulan, lalu heatmap

# %% [markdown]
# ### Jawab di sini — Insight 3.6
#
# **Dari heatmap ini, bulan apa yang paling ramai untuk kategori tertentu? Ada pola musiman yang terlihat?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ### 3.7 Crosstab — Status Pesanan vs Bulan
#
# > **Tip:** Gunakan `pd.crosstab()` untuk menghitung frekuensi kombinasi dua variabel kategorik:
# > ```python
# > ct = pd.crosstab(df['order_status'], df['month_only'])
# > ```
# >
# > Tampilkan crosstab-nya, lalu buat bar chart dari baris status utama saja:
# > `['delivered', 'canceled', 'shipped']`

# %%
# crosstab order_status vs month_only, lalu visualisasi bar chart

# %% [markdown]
# ### Jawab di sini — Insight 3.7
#
# **Apakah ada pola cancellation yang menarik? Bulan mana yang cancellation-nya tinggi? Apa kemungkinan penyebabnya?**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ---
# # Section 4 — Data Storytelling
#
# Ini section yang paling penting dalam exam ini.
#
# Kamu sudah melakukan analisis. Sekarang saatnya **ceritakan apa yang kamu temukan** — seperti kamu sedang presentasi ke atasan atau klien bisnis e-commerce.
#
# Tulis dalam bentuk narasi yang mengalir. Bukan sekadar daftar angka.
#
# ---
#
# ## Business Questions yang Harus Dijawab
#
# Pilih dan jawab **minimal 3** dari pertanyaan berikut:
#
# 1. Kategori produk apa yang paling menguntungkan dan kenapa?
# 2. Kapan puncak penjualan terjadi — dan apa kemungkinan penyebabnya?
# 3. Bagaimana performa pengiriman secara keseluruhan?
# 4. Apakah ada kategori produk yang ongkos kirimnya tidak efisien?
# 5. Pertanyaan lain yang kamu temukan sendiri dari data *(bonus poin!)*

# %% [markdown]
# ### Jawab di sini — Business Question 1
#
# **Pertanyaan yang kamu pilih:**
#
# > *Klik 2x di sini untuk menulis jawabanmu*
#
#
# **Temuan:**
#
# > *Klik 2x di sini untuk menulis jawabanmu*
#
#
# **Rekomendasi:**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ### Jawab di sini — Business Question 2
#
# **Pertanyaan yang kamu pilih:**
#
# **Temuan:**
#
# **Rekomendasi:**

# %% [markdown]
# ### Jawab di sini — Business Question 3
#
# **Pertanyaan yang kamu pilih:**
#
# **Temuan:**
#
# **Rekomendasi:**

# %% [markdown]
# ---
# ### Jawab di sini — Kesimpulan Akhir
#
# > Bayangkan kamu sedang menyampaikan ini ke CEO perusahaan e-commerce.
# > Gunakan bahasa yang jelas, padat, dan berbasis data.
#
# **Ringkasan Temuan Utama:**
#
# 1. isi di sini
# 2. isi di sini
# 3. isi di sini
#
# ---
#
# **Rekomendasi Bisnis:**
#
# 1. isi di sini
# 2. isi di sini
# 3. isi di sini
#
# ---
#
# **Limitasi Analisis:**
#
# > *Klik 2x di sini untuk menulis jawabanmu*

# %% [markdown]
# ---
# # Bonus (Opsional)
#
# Kalau sudah selesai dan masih ada waktu:
#
# - Analisis waktu pengiriman: selisih antara `order_purchase_timestamp` dan `order_delivered_customer_date`
# - Analisis korelasi antara berat produk (`product_weight_g`) dan ongkos kirim (`freight_value`)
# - Buat visualisasi lebih kreatif (scatter plot, violin plot, dll)
# - Temukan insight lain yang belum dianalisis di atas

# %%
# tulis analisis bonus kamu di sini
